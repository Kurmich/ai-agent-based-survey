# %%
import numpy as np
import pandas as pd

# %%
data_dir = './associatedpress-covid-impact-survey-public-data'
data_files = dict()
data_files['april'] = '01_April_30_covid_impact_survey.csv'
data_files['may']   = '02_May_12_covid_impact_survey.csv'
data_files['june']  = '03_June_9_covid_impact_survey.csv'

# %%
data_april = data_dir + '/' + data_files['april']
df_april = pd.read_csv(data_april)
# Out:
# /var/folders/0f/lqjqfrb16p5gf3__wqf2c94h1tfy6x/T/ipykernel_49761/1792841620.py:2: DtypeWarning: Columns (96,156,168,170) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_april = pd.read_csv(data_april)

# %%
list(df_april)
# Out:
# ['Unnamed: 0',
#  'SU_ID',
#  'P_PANEL',
#  'NATIONAL_WEIGHT',
#  'REGION_WEIGHT',
#  'NATIONAL_WEIGHT_POP',
#  'REGION_WEIGHT_POP',
#  'P_GEO',
#  'SOC1',
#  'SOC2A',
#  'SOC2B',
#  'SOC3A',
#  'SOC3B',
#  'SOC4A',
#  'SOC4B',
#  'PHYS8',
#  'PHYS1A',
#  'PHYS1B',
#  'PHYS1C',
#  'PHYS1D',
#  'PHYS1E',
#  'PHYS1F',
#  'PHYS1G',
#  'PHYS1H',
#  'PHYS1I',
#  'PHYS1J',
#  'PHYS1K',
#  'PHYS1L',
#  'PHYS1M',
#  'PHYS1N',
#  'PHYS1O',
#  'PHYS1P',
#  'PHYS1Q',
#  'SOC5A',
#  'SOC5B',
#  'SOC5C',
#  'SOC5D',
#  'SOC5E',
#  'PHYS2_1',
#  'PHYS2_2',
#  'PHYS2_3',
#  'PHYS2_4',
#  'PHYS2_5',
#  'PHYS2_6',
#  'PHYS2_7',
#  'PHYS2_8',
#  'PHYS2_9',
#  'PHYS2_10',
#  'PHYS2_11',
#  'PHYS2_12',
#  'PHYS2_13',
#  'PHYS2_14',
#  'PHYS2_15',
#  'PHYS2_16',
#  'PHYS2_17',
#  'PHYS2_18',
#  'PHYS2_19',
#  'PHYS2_DK',
#  'PHYS2_SKP',
#  'PHYS2_REF',
#  'PHYS10A',
#  'PHYS10B',
#  'PHYS10C',
#  'PHYS10D',
#  'PHYS10E',
#  'ECON8A',
#  'ECON8B',
#  'ECON8C',
#  'ECON8D',
#  'ECON8E',
#  'ECON8F',
# ...

# %%
print(len(list(df_april)))
print(list(df_april)[8:])
# Out:
# 174
# ...

# %%
import re

def filter_nonnumerical(text):
    if not isinstance(text, str):
        return text
    pattern = r"\((\d+)\)"
    match = re.search(pattern, text)
    if match:
        return match.group(1)
    return text

print(filter_nonnumerical('(3) Some'))
print(filter_nonnumerical('(98) SKIPPED ON WEB'))

df_april['SOC1']= df_april['SOC1'].apply(filter_nonnumerical)
# Out:
# 3
# 98

# %%
columns_to_clean = list(df_april)[8:]
def clean_columns(df, columns_to_clean):
    for col in columns_to_clean:
        df[col]= df[col].apply(filter_nonnumerical)

clean_columns(df_april, columns_to_clean)
print(df_april.head())
# Out:
#    Unnamed: 0     SU_ID P_PANEL  NATIONAL_WEIGHT  REGION_WEIGHT  \
# 0           1  20001173     ABS              NaN       1.218648
# 1           2  20002089     ABS              NaN       0.228867
# 2           3  20002704     ABS              NaN       0.251659
# 3           4  20002713     ABS              NaN       0.207222
# 4           5  20003003     ABS              NaN       3.385956
#
#    NATIONAL_WEIGHT_POP  REGION_WEIGHT_POP                           P_GEO  \
# 0                  NaN       41103.599135                        New York
# 1                  NaN        3127.867402  Phoenix-Mesa-Chandler, Arizona
# 2                  NaN        1960.942970                          Oregon
# 3                  NaN         958.491227        Pittsburgh, Pennsylvania
# 4                  NaN       10720.255694          Cleveland-Elyria, Ohio
#
#   SOC1 SOC2A  ... REGION9 P_DENSE MODE LANGUAGE MAIL50 RACE1_BANNER  \
# ...

# %%
print(df_april['RACE2_BANNER'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 8785      1
# 8786      9
# 8787      1
# 8788      1
# 8789      1
# Name: RACE2_BANNER, Length: 8790, dtype: object

# %%
df_april.to_csv('clean_april.csv')
